# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bridgit.games.bridgit.game import BridgitGame, BridgitGameState
from bridgit.games.bridgit.player import Player
from bridgit.games.bridgit.config import BoardConfig

# %% [markdown]
# ### State

# %%
game = BridgitGame()
game_state = game._state

# %%
game_state.visualize()

# %%
new_state = game_state.make_move(1, 1, Player.HORIZONTAL)

# %%
new_state.visualize()

# %%
new_state.to_mask()

# %%
new_state.to_tensor()

# %%
canonical = new_state.canonical(Player.VERTICAL)

# %%
canonical.visualize()

# %% [markdown]
# ### Game

# %%
game = BridgitGame()

# %%
game.visualize()

# %%
game.make_action(game.row_col_to_action(1, 1))
game.visualize()
game.make_action(game.row_col_to_action(2, 2))
game.visualize()
game.make_action(game.row_col_to_action(3, 3))
game.visualize()
