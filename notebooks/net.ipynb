# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bridgit import Bridgit, GameState, Player
from bridgit.ai import BridgitNet, NetWrapper
import torch

# %%
net = BridgitNet()
net.eval()
wrapper = NetWrapper(net)
game = Bridgit()

# %%
net = BridgitNet()
net.eval()
wrapper = NetWrapper(net)
game = Bridgit()

while not game.game_over:
    row, col = wrapper.make_move(game.state, game.current_player)
    game.make_move(row, col)
    game.visualize()

print(f"Winner: {game.winner.name}")
# Out:
# Winner: HORIZONTAL
